# %% [markdown]
# # cse-221710305019-siddharth venkat
#
#
# Use the following csv file link for solving the given problem using python code https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv")
df
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# ..        ...       ...                          ...
# 632       632   1082646             Delhi Daredevils
# 633       633   1082647               Mumbai Indians
# 634       634   1082648          Sunrisers Hyderabad
# 635       635   1082649               Mumbai Indians
# 636       636   1082650               Mumbai Indians
#
#                            Team2 match_date  Season_Year  \
# 0          Kolkata Knight Riders  4/18/2008         2008
# 1            Chennai Super Kings  4/19/2008         2008
# 2               Rajasthan Royals  4/19/2008         2008
# 3    Royal Challengers Bangalore  4/20/2008         2008
# ...

# %%
#Question 1:Print ManOfMach count of each player in Hyderabad stadium

# %%
df1=df[df['City_Name']=='Hyderabad']

# %%
df1
# Out:
#      Match_SK  match_id                Team1                        Team2  \
# 6           6    335993      Deccan Chargers             Delhi Daredevils
# 8           8    335995      Deccan Chargers             Rajasthan Royals
# 17         17    336004      Deccan Chargers              Kings XI Punjab
# 20         20    336007      Deccan Chargers  Royal Challengers Bangalore
# 32         32    336019      Deccan Chargers        Kolkata Knight Riders
# 42         42    336029      Deccan Chargers               Mumbai Indians
# 54         54    336042      Deccan Chargers          Chennai Super Kings
# 176       176    501204      Deccan Chargers             Rajasthan Royals
# 185       185    501213      Deccan Chargers  Royal Challengers Bangalore
# 189       189    501217      Deccan Chargers              Kings XI Punjab
# 200       200    501229      Deccan Chargers               Mumbai Indians
# 215       215    501244      Deccan Chargers        Kolkata Knight Riders
# ...

# %%
#df1['ManOfMach'].value_counts()

# %%
#df1.groupby('ManOfMach').size()

# %%
df2=pd.DataFrame(df1.groupby('ManOfMach').size().reset_index().values, columns=["Players", "No of man of the matches"])

# %%
df2
# Out:
#               Players No of man of the matches
# 0            A Mishra                        2
# 1            AB Dinda                        1
# 2           AT Rayudu                        1
# 3             B Kumar                        1
# 4           CH Morris                        1
# 5           DA Warner                        6
# 6            DJ Bravo                        1
# 7           DJG Sammy                        1
# 8            DW Steyn                        3
# 9           G Gambhir                        1
# 10          GH Vihari                        2
# 11           I Sharma                        1
# 12     MJ McClenaghan                        1
# 13           MR Marsh                        1
# 14      Mandeep Singh                        1
# 15  Mustafizur Rahman                        1
# 16           PA Patel                        1
# 17        PC Valthaty                        1
# 18      R Vinay Kumar                        1
# ...

# %%
#Question 2: Plot a pie chart for the country_name column

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
val=df.groupby('Country_Name').size()
v=list(val)
c=list(val.index)
plt.pie(v,labels=c,autopct="%0.1f%%",radius=1.5,
       colors=["red","blue","green",],
explode=[0.1,0,0],
       startangle=45)
plt.show()
